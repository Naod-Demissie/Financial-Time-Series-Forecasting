# %% [markdown]
# # <center><font color = '#DF9166' size = 20 center> **Data Exploration**</font></center>

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Table of content**<font/><a class = 'anchor' id = 'introduction'/>

# %% [markdown]
# 1. [**Import Libraries**](#import)
# 2. [**Data Loading**](#data_loading)
# 3. [**Exploratory Data Analysis**](#eda)

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Import Libraries**<font/><a class = 'anchor' id = 'import'/>

# %%
import os
import sys
import pandas as pd

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

# %%
sys.path.append(os.path.abspath(os.path.pardir))
from scripts.explore_data import FinancialEDA

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Data Loading**<font/><a class = 'anchor' id = 'data_loading'/>

# %%
eda = FinancialEDA("../data/raw/TSLA.csv", "../data/raw/BND.csv", "../data/raw/SPY.csv")

# %%
eda.tsla_data.head(2)
# Out:
#                 Close       High        Low       Open    Volume
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500

# %%
eda.spy_data.head(2)
# Out:
#                  Close        High         Low        Open     Volume
# Date
# 2015-01-02  172.592865  173.811099  171.542672  173.391022  121465900
# 2015-01-05  169.475876  171.702279  169.165023  171.534251  169632600

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Exploratory Data Analysis**<font/><a class = 'anchor' id = 'eda'/>

# %%
eda.calculate_daily_returns()

# %%
eda.plot_closing_prices()

# %%
eda.plot_daily_returns()

# %%
eda.rolling_statistics()

# %%
eda.detect_outliers()

# %%
eda.seasonal_decompose()

# %%
eda.risk_analysis()
# Out:
# Risk Metrics for TSLA:
# Mean Daily Return: 0.00195
# Standard Deviation: 0.03601
# 95% Value at Risk (VaR): -0.05727
# Sharpe Ratio: 0.05
# --------------------------------------------------
# Risk Metrics for BND:
# Mean Daily Return: 0.00006
# Standard Deviation: 0.00343
# 95% Value at Risk (VaR): -0.00557
# Sharpe Ratio: -0.00
# --------------------------------------------------
# Risk Metrics for SPY:
# Mean Daily Return: 0.00056
# Standard Deviation: 0.01108
# 95% Value at Risk (VaR): -0.01767
# Sharpe Ratio: 0.04
# --------------------------------------------------
