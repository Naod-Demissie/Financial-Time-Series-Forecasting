# %% [markdown]
# # <center><font color = '#DF9166' size = 20 center> **Optimize Portfolio**</font></center>

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Table of content**<font/><a class = 'anchor' id = 'introduction'/>

# %% [markdown]
# 1. [**Import Libraries**](#import)
# 2. [**Optimize Portfolio**](#optimize)

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Import Libraries**<font/><a class = 'anchor' id = 'import'/>

# %%
import os
import sys
import warnings

warnings.filterwarnings("ignore")

# %%
sys.path.append(os.path.abspath(os.path.pardir))
from scripts.optimize_portfolio import PortfolioOptimizer

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Optimize Portfolio**<font/><a class = 'anchor' id = 'optimize'/>

# %%
# Define file paths
model_path = "/content/drive/MyDrive/10 acadamy/W11 Challenge/checkpoints/LSTM_model.h5"
data_paths = {
    "TSLA": "/content/drive/MyDrive/10 acadamy/W11 Challenge/data/processed/TSLA.csv",
    "BND": "/content/drive/MyDrive/10 acadamy/W11 Challenge/data/processed/BND.csv",
    "SPY": "/content/drive/MyDrive/10 acadamy/W11 Challenge/data/processed/SPY.csv",
}

# %%
# Initialize and run the optimizer with a forecast horizon (e.g., 10 days)
optimizer = PortfolioOptimizer(model_path, data_paths, forecast_horizon=10)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loading model from /content/drive/MyDrive/10 acadamy/W11 Challenge/checkpoints/LSTM_model.h5...
# Model loaded successfully!
# Loaded datasets for TSLA, BND, and SPY.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ...

# %%
optimal_weights = optimizer.optimize_portfolio()
# Out:
# Computed annualized returns:
# TSLA   -16.339073
# BND     -7.207667
# SPY    -20.800529
# dtype: float32
# Computed annualized covariance matrix:
#           TSLA       BND       SPY
# TSLA  0.028781  0.021366  0.047262
# BND   0.021366  0.016023  0.035313
# SPY   0.047262  0.035313  0.078002
# Computed annualized returns:
# TSLA   -16.339073
# BND     -7.207667
# SPY    -20.800529
# dtype: float32
# Computed annualized covariance matrix:
#           TSLA       BND       SPY
# TSLA  0.028781  0.021366  0.047262
# BND   0.021366  0.016023  0.035313
# SPY   0.047262  0.035313  0.078002
# Computed annualized returns:
# TSLA   -16.339073
# BND     -7.207667
# SPY    -20.800529
# dtype: float32
# Computed annualized covariance matrix:
#           TSLA       BND       SPY
# TSLA  0.028781  0.021366  0.047262
# BND   0.021366  0.016023  0.035313
# SPY   0.047262  0.035313  0.078002
# Computed annualized returns:
# TSLA   -16.339073
# BND     -7.207667
# SPY    -20.800529
# dtype: float32
# ...

# %%
optimizer.summary(optimal_weights)
# Out:
# Computed annualized returns:
# TSLA   -16.339073
# BND     -7.207667
# SPY    -20.800529
# dtype: float32
# Computed annualized covariance matrix:
#           TSLA       BND       SPY
# TSLA  0.028781  0.021366  0.047262
# BND   0.021366  0.016023  0.035313
# SPY   0.047262  0.035313  0.078002
# Portfolio Optimization Summary:
# Expected Annual Return: -7.2077
# Expected Volatility: 0.1266
# Sharpe Ratio: -56.9412

# %%
optimizer.visualize_portfolio_performance(optimal_weights)
# Out:
# Displayed cumulative return chart.
